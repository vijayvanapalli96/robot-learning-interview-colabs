# %% [markdown]
# # 00 - Interview Map\n\nNorth star: **I am strongest where perception and deployment meet robot learning. I can help build the systems that make learned policies work on real hardware.**

# %% [markdown]
# ## 90-second spine\n\n- **VLM:** image + text -> text. Usually vision encoder -> projector/adapter -> LLM.\n- **VLA:** image + instruction + robot state -> action or action chunks.\n- **Robot learning:** demonstrations -> behavior cloning -> evaluation -> corrections -> safe rollout.\n- **Hierarchy:** high-level subgoals + low-level execution.\n- **Deployment:** latency, calibration, safety, logging, failure analysis.

# %%
sections = {\n    'VLM': ['vision encoder', 'projector / adapter', 'LLM text generation'],\n    'VLA': ['multi-camera observations', 'language instruction', 'robot state', 'action chunks'],\n    'Robot learning': ['teleop demos', 'behavior cloning baseline', 'failure analysis', 'targeted corrections'],\n    'Hierarchy': ['approach', 'align', 'contact', 'push', 'turn', 'stop', 'recover'],\n    'Deployment': ['latency', 'safety constraints', 'calibration', 'logging', 'evaluation']\n}\n\nfor name, bullets in sections.items():\n    print(f'\\n{name}')\n    for b in bullets:\n        print(f'  - {b}')

# %% [markdown]
# ## Rehearsal prompt\n\nSay this out loud in under 90 seconds:\n\n> A VLM maps image and text to language. A VLA extends that to robot control by adding robot state and action supervision from demonstrations. The hard parts become action representation, demonstration quality, embodiment differences, latency, safety, and real-world evaluation.
