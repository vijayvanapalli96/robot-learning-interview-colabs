# %% [markdown]
# # 05 - Optional nanoVLM Code Reading\n\nUse this only if setup stays clean. Stop after 20 minutes if dependencies get annoying.

# %% [markdown]
# ## Reading questions\n\n- Where is the vision encoder?\n- Where is the projector?\n- Where are visual tokens inserted?\n- What loss is used?\n- What is trained?\n- What remains frozen, if anything?

# %%
# Optional setup sketch. Uncomment only when you are ready to inspect the repo.\n# !git clone https://github.com/huggingface/nanoVLM.git\n# %cd nanoVLM\n# !find . -maxdepth 2 -type f | sort | head -50

# %% [markdown]
# ## Enough to explain\n\n```python\nfor image, question, answer in dataset:\n    visual_tokens = vision_encoder(image)\n    projected_tokens = projector(visual_tokens)\n    logits = llm(projected_tokens, question_tokens)\n    loss = cross_entropy(logits, answer_tokens)\n    loss.backward()\n```
